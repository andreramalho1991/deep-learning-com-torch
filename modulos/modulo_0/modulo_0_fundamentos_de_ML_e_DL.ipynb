# %% [markdown]
# <a href="https://colab.research.google.com/github/andreramalho1991/deep-learning-com-torch/blob/main/modulos/modulo_0/modulo_0_fundamentos_de_ML_e_DL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Learning com PyTorch

# %% [markdown]
# ## 00. Módulo 0 - Fundamentos de Machine Learning e Deep Learning

# %% [markdown]
# O que você encontrará nesse módulo:
# * Diferença entre Inteligência Artificial, Machine Learning e Deep Learning;
# * Tipos de aprendizado de máquina;
# * Tipos de tarefas realizadas por modelos de aprendizado de máquina; e
# * Introdução ao Pytorch.

# %% [markdown]
# ###  Inteligência Artificial vs. Machine Learning vs. Deep Learning

# %% [markdown]
# 1. **Inteligência Artificial (IA):** É o campo geral da ciência da computação que busca criar sistemas capazes de mimetizar o raciocínio e comportamento humano ao realizar tarefas que, se feitas por seres humanos, exigiriam inteligência. Isso envolve a criação de algoritmos e programas que podem tomar decisões, resolver problemas e aprender com experiências.
#
# 2. **Machine Learning (Aprendizado de Máquina):** É uma subárea da IA que se concentra no desenvolvimento de algoritmos que permitem que um sistema aprenda e melhore seu desempenho em uma tarefa específica à medida que mais dados são processados. Isso é feito sem programação explícita para cada situação, mas sim através da análise de padrões nos dados.
#
# 3. **Deep Learning:** É uma subárea do Aprendizado de Máquina baseada em redes neurais artificiais profundas para aprender representações complexas dos dados. Essas redes, chamadas de redes neurais profundas, são compostas por várias camadas e são especialmente eficazes em tarefas que envolvem dados não estruturados, como imagens, áudio e texto.
#
#
# > 🔑 A IA é o campo mais amplo que busca criar sistemas inteligentes que mimetizem o comportamento humano, o Aprendizado de Máquina é uma técnica dentro da IA que se concentra no aprendizado a partir de dados, e o Deep Learning é uma abordagem poderosa de Aprendizado de Máquina que utiliza redes neurais profundas para aprender representações complexas dos dados.
#
# De forma visual, podemos expressar a relação entre os três tópicos da seguinte forma:

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,7))
ax.axis('off')

plt.title('Relação entre Inteligência Artificial, Machine Learnig e Deep Learning')

ia = plt.Circle((0.5, 0.5), 0.4, color='orange', alpha =0.3)
ax.add_patch(ia)
plt.annotate('Inteligência Artificial', xy=(0.1, 0.5), xytext=(0.1, 0.5))

ml = plt.Circle((0.6, 0.5), 0.3, color='red', alpha =0.3)
ax.add_patch(ml)
plt.annotate('Machine Learning', xy=(0.3, 0.5), xytext=(0.3, 0.5))

dl = plt.Circle((0.7, 0.5), 0.2, color='blue', alpha =0.3)
ax.add_patch(dl)
plt.annotate('Deep Learning', xy=(0.5, 0.5), xytext=(0.5, 0.5))

plt.show()

# %% [markdown]
# ### Tipos de Aprendizado de Máquina

# %% [markdown]
# 🔑 Existem três principais tipos de aprendizado de máquina:
#
# > **Aprendizado Supervisionado:** Os modelos são treinados com dados rotulados, aprendendo a mapear entradas para saídas, sendo útil para classificação e regressão.
#
# > **Aprendizado Não Supervisionado:**  Os modelos encontram padrões em dados não rotulados, agrupando-os ou reduzindo sua dimensionalidade, usado para clusterização e redução de dimensionalidade.
#
# > **Aprendizado por Reforço:** Agentes aprendem a tomar decisões em ambientes dinâmicos, recebendo recompensas ou penalidades, sendo aplicado em jogos e controle de robôs, por exemplo.
#
# Durante os próximos módulos aboradaremos o desenvolvimento de Redes Neurais Artificiais para os dois primeiros tipos de aprendizado (supervisionado e não supervisionado).

# %% [markdown]
# #### Exemplos de Aplicação dos tipos de aprendizado de Máquina
#
# 1. Aprendizado Supervisionado:
#
# * **Classificação de E-mails:** Um modelo é treinado para classificar e-mails como spam ou não spam com base em exemplos rotulados.
# * **Previsão de Preços Imobiliários:** Usando dados históricos, um modelo prevê o preço de casas com base em suas características.
# * **Detecção de Fraudes em Cartões de Crédito:** Um modelo aprende com transações rotuladas como fraudulentas ou não e identifica transações suspeitas.
# * **Diagnóstico Médico:** Utilizando imagens médicas rotuladas, um modelo auxilia no diagnóstico de doenças, como câncer, a partir de exames de imagem.
# * **Tradução Automática:** Modelos traduzem texto de um idioma para outro com base em pares de frases traduzidas anteriormente.
#
# 2. Aprendizado Não-Supervisionado
#
# * **Clusterização de Clientes:** Um algoritmo agrupa clientes com base em seus padrões de compra sem a necessidade de rótulos prévios.
# * **Análise de Tópicos em Texto:** O algoritmo extrai automaticamente tópicos de grandes volumes de texto não rotulado.
# * **Segmentação de Imagens:** Segmentação de imagens em regiões com base em semelhanças de cores e texturas.
# * **Detecção de Anomalias de Equipamentos:** Identificação de falhas em máquinas industriais com base em dados de sensores.
# * **Recomendação de Conteúdo:** Sistemas de recomendação recomendam produtos ou conteúdo com base nos padrões de consumo do usuário, sem rótulos explícitos.
#
# 3. Aprendizado por Reforço:
#
# * **Jogos de Tabuleiro:** Agentes de aprendizado por reforço, como o AlphaZero, aprendem a jogar xadrez e Go com base em recompensas.
# * **Controle de Robôs:** Robôs autônomos aprendem a realizar tarefas físicas, como caminhar ou voar, através de tentativa e erro.
# * **Treinamento de Carros Autônomos:** Veículos autônomos aprendem a navegar no trânsito e seguir rotas com base em recompensas por decisões seguras.
# * **Aprendizado de Estratégia de Investimento:** Agentes de aprendizado por reforço podem aprender a tomar decisões de investimento em ações.
# * **Jogos de Vídeo:** Agentes de aprendizado por reforço jogam jogos de vídeo, como Dota 2, aprendendo a jogar com eficiência e derrotar adversários.

# %% [markdown]
# ### Tarefas Executadas por Modelos de Aprendizagem de Máquina

# %% [markdown]
# * **Classificação:** O modelo atribui rótulos ou categorias a dados de entrada com base em padrões aprendidos.
#
#     > *Exemplo: classificar e-mails como spam ou não spam.*
#
# * **Regressão:** O modelo prevê valores numéricos com base em dados de entrada.
#
#     > *Exemplo: prever o preço de uma casa com base em suas características.*
#
# * **Clusterização:** O modelo agrupa dados semelhantes em clusters, identificando estruturas subjacentes.
#
#     > *Exemplo: agrupar clientes com base em seus hábitos de compra.*
#
# * **Redução de Dimensionalidade:** O modelo reduz a complexidade dos dados, mantendo as informações essenciais.
#
#     > *Exemplo: aplicar PCA para simplificar dados multidimensionais.*
#
# * **Análise de Sentimento:** O modelo determina o sentimento (positivo, negativo, neutro) em texto ou dados.
#
#     > *Exemplo: avaliar opiniões de clientes sobre um produto.*
#
# * **Detecção de Anomalias:** O modelo identifica padrões incomuns ou anômalos nos dados.
#
#     > *Exemplo: detectar transações de cartão de crédito fraudulentas.*
#
# * **Processamento de Linguagem Natural (PLN):** O modelo processa e compreende texto humano, realizando tarefas como tradução, sumarização e análise de entidades.
#     > *Exemplo: Moderação de postagem em redes sociais.*
#
# * **Visão Computacional:** O modelo interpreta e compreende imagens ou vídeos, podendo identificar objetos, rostos ou realizar reconhecimento de padrões.
#
#     > *Exemplo: Reconhecimento facial.*
#
# * **Aprendizado por Reforço:** O modelo toma decisões sequenciais para maximizar recompensas em ambientes dinâmicos.
#
#     > *Exemplo: treinar agentes para jogar jogos.*
#
# * **Geração de Conteúdo:** O modelo cria novos dados, como texto, imagens ou música, com base em exemplos existentes.
#
#     > *Exemplo: ChatGPT, DALLE, Midjourney, etc.*
#
# * **Tradução Automática:** O modelo traduz texto de um idioma para outro.
#
#     > *Exemplo: Google Tradutor.*
#
# * **Recomendações:** O modelo sugere produtos, filmes, músicas, etc., com base no histórico e preferências do usuário.
#
#     > *Exemplo: Sugestão de filmes feita pela Netflix ou músicas pelo Spotfy.*

# %% [markdown]
# ### Introdução ao Pytorch (Crash course)

# %% [markdown]
# #### Primeiros passos

# %% [markdown]
# Para esse curso, utilizaremos primariamente o Google Colab, no entanto, caso prefira utilizar um ambiente virtual local e/ou não possua o pytorch instalado, descomente a linha de código abaixo.
#
# > Para maiores informações de como criar um ambiente virtuaL, segue tutorial: https://www.geeksforgeeks.org/create-virtual-environment-using-venv-python/
#
#
# > Para maiores informações de como instalar o pytorch, segue link: https://pytorch.org/get-started/locally/
#
# ![image.png](data:image/png;base64,...)

# %%
# !pip install pytorch

# %%
import torch
torch.__version__
# Out:
# '2.0.1+cu118'
